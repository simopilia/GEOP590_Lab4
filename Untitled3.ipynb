# %% [markdown]
# # Lab 3: Ambient noise tomography of Lake Toba
#
# The goal of this Lab is to introduce you to the package SeisLib, a collection of Python libraries that will allow you to download and process ambient noise data from publicly available stations, compute cross-correlations, extract phase velocities and invert for velocity structures. Many other functionalities exist, please visit the following web-page for a comprehensive documentation and whenever you encounter an issue:
# https://seislib.readthedocs.io/en/latest/

# %%
# As usual, we begin by importing the libraries we need 
import numpy as np
from obspy import UTCDateTime as UTC
from seislib.an import ANDownloader
from seislib.an import AmbientNoiseVelocity
import matplotlib.pyplot as plt
from seislib.tomography import RegularGrid
from seislib.tomography import SeismicTomography

# %% [markdown]
# ## Step 1: Download seismic data
#
# To begin with, we have to download the continuous seismic records from one or more networks. This is done by first creating a dictionary that contains the information about our study area (i.e., where we want to search for data), and subsequently invoking the function ANDownloader to download the data in our local machine. Note that downloading the data typically takes several days.
#
# Check out more info about the seismic data (and the region where the stations were deployed) we are using from the following website https://www.fdsn.org/networks/detail/7A_2008/

# %%
stations_config = dict(network='7A', #network name
                       channel='EHZ', # we are only extracting vertical component data (this could take different forms, e.g. BHZ)
                       starttime=UTC(2008, 1, 1), # collect data from this date to endtime
                       endtime=UTC(2009, 1, 2),
                       includerestricted=False,
                       maxlatitude=3.5, # define search area for data
                       minlatitude=1.5,
                       minlongitude=97,
                       maxlongitude=100)

# %%
# This is the cell that will download the data. See SeisLib manual for all different options.
downloader = ANDownloader(savedir='/Users/simone/iCloud/Documents/Teaching/2023_2024/Seismic_Tomography/Lab/download', 
                          inventory_name='7A.xml',
                          provider='gfz',
                          sampling_rate=1,
                          prefilter=(0.005, 0.01, 0.5, 1),
                          units='disp',
                          attach_response=False,
                          stations_config=stations_config,
                          verbose=True)
downloader.start()

# %% [markdown]
# We have now downloaded and stored the seismic records in the folder defined by savedir. We have our main ingredient to perform ambient noise tomography, the data!

# %% [markdown]
# ## Step 2: Inter-Station Dispersion Curves
#
# At this stage, SeisLib is essentially ready to extract the dispersion curves. While it may appear that some steps are missed, SeisLib does everything in the background (e.g., computing the cross-correlations).

# %%
src = '/Users/simone/iCloud/Documents/Teaching/2023_2024/Seismic_Tomography/GEOP590_Lab4/download/data'
an = AmbientNoiseVelocity(
         src=src,
         component='Z')
print(an)
# Out:
# RAYLEIGH-WAVE VELOCITY FROM SEISMIC AMBIENT NOISE
# ==================================================
# RECEIVERS: 42
# STATION PAIRS AVAILABLE: 861
# DISPERSION CURVES RETRIEVED: 331
# ==================================================
# SOURCE DIR: /Users/simone/iCloud/Documents/Teaching/2023_2024/Seismic_Tomography/Lab/download/data
# SAVE DIR: /Users/simone/iCloud/Documents/Teaching/2023_2024/Seismic_Tomography/Lab/download/an_velocity/Z

# %%
an.prepare_data()

# %%
ref_curve = np.load('rayleigh_asia.npy')
#print (ref_curve)
#ref_curve= np.array([[0.001, 3.5],
#                [0.05, 3.0],
#                 [0.10, 2.5],
#                 [0.15, 2.0],
#                 [0.2, 2.0],
#                 [0.5, 2.0]])

# %%
#an.extract_dispcurves(refcurve=ref_curve, 
#                      freqmin=0.01, 
###                      freqmax=0.5, 
#                      cmin=1.5,
#                      cmax=4.0, 
#                      distmax=1000, 
#                      window_length=3600, 
##                      overlap=0.5, 
#                      min_no_days=30,
#                      save_xcorr=True,
#                      plotting=True)

# %%
#an.plot_stations()

# %% [markdown]
# ## Plotting of the cross-correlations in the frequency domain

# %%
# Remember we are working with the cross-spectrum here, essentially the Fourier transform of the cross-correlation of two signals.
xcorr = np.load('/Users/simone/iCloud/Documents/Teaching/2023_2024/Seismic_Tomography/Lab/download/an_velocity/Z/xcorr/7A.LT01..EHZ__7A.LT06..EHZ.npy')

#Plot the real and ima
plt.figure(figsize=(10, 6))
plt.plot(xcorr[:,0], xcorr[:,1].real, 'k', lw=1.5, label='Real')
plt.plot(xcorr[:,0], xcorr[:,1].imag, 'gray', lw=1.5, label='Imag')
plt.xlabel('Frequency [Hz]')
plt.grid(alpha=0.5)
plt.legend(loc='upper right', framealpha=0.9, handlelength=1)
plt.title('Cross Spectrum')
plt.grid(True)
plt.show()

# %% [markdown]
# ## Prepare input for tomography

# %%
savedir = '/Users/simone/iCloud/Documents/Teaching/2023_2024/Seismic_Tomography/Lab/download/an_velocity/tomo'
periods = [4, 8, 12]
an.prepare_input_tomography(savedir=savedir,
                            period=periods)
# Out:
# FILES PROCESSED: 0/727
# FILES PROCESSED: 37/727
# FILES PROCESSED: 74/727
# FILES PROCESSED: 111/727
# FILES PROCESSED: 148/727
# FILES PROCESSED: 185/727
# FILES PROCESSED: 222/727
# FILES PROCESSED: 259/727
# FILES PROCESSED: 296/727
# FILES PROCESSED: 333/727
# FILES PROCESSED: 370/727
# FILES PROCESSED: 407/727
# FILES PROCESSED: 444/727
# FILES PROCESSED: 481/727
# FILES PROCESSED: 518/727
# FILES PROCESSED: 555/727
# FILES PROCESSED: 592/727
# FILES PROCESSED: 629/727
# FILES PROCESSED: 666/727
# FILES PROCESSED: 703/727
# Measurements at 4.00s: 273
# Measurements at 8.00s: 457
# Measurements at 12.00s: 285

# %% [markdown]
# ## Parametrise the model

# %%
from seislib.tomography import RegularGrid
grid = RegularGrid(cell_size=0.15, 
                       latmin=1.5,
                       latmax=3.5,
                       lonmin=97,
                       lonmax=100,
                       verbose=True)
# Out:
# -------------------------------------
# GRID PARAMETERS
# Lonmin - Lonmax : 97.000 - 100.000
# Latmin - Latmax : 1.500 - 3.600
# Number of cells : 280
# Grid cells of 0.150° : 280
# -------------------------------------

# %%
print(grid.mesh)

# We can refine the mesh by simply doing:
grid.refine_mesh([0, 1], inplace=True)
print(grid.mesh)
#grid.plot(projection='Mercator') # Grid can be easily plot using this command.
# Out:
# [[  3.5625   3.6     97.      97.0375]
#  [  3.5625   3.6     97.0375  97.075 ]
#  [  3.525    3.5625  97.      97.0375]
#  ...
#  [  1.5      1.65    99.55    99.7   ]
#  [  1.5      1.65    99.7     99.85  ]
#  [  1.5      1.65    99.85   100.    ]]
# *** GRID UPDATED ***
# -------------------------------------
# GRID PARAMETERS
# Lonmin - Lonmax : 97.000 - 100.000
# Latmin - Latmax : 1.500 - 3.600
# Number of cells : 298
# Grid cells of 0.150° : 278
# Grid cells of 0.075° : 6
# Grid cells of 0.037° : 6
# Grid cells of 0.019° : 8
# -------------------------------------
# [[  3.58125   3.6      97.       97.01875]
#  [  3.58125   3.6      97.01875  97.0375 ]
#  [  3.5625    3.58125  97.       97.01875]
#  ...
#  [  1.5       1.65     99.55     99.7    ]
#  [  1.5       1.65     99.7      99.85   ]
#  [  1.5       1.65     99.85    100.     ]]

# %%
from seislib.tomography import SeismicTomography
tomo = SeismicTomography(cell_size=0.5, regular_grid=False, verbose=True)
tomo.add_data(src='/Users/simone/iCloud/Documents/Teaching/2023_2024/Seismic_Tomography/Lab/download/an_velocity/tomo/input_4.00s.txt')
# Out:
# -------------------------------------
# Optimal grid found in 181 iterations
# -------------------------------------
# -------------------------------------
# GRID PARAMETERS
# Lonmin - Lonmax : -180.000 - 180.000
# Latmin - Latmax : -90.000 - 90.000
# Number of cells : 165016
# Grid cells of 0.500° : 165016
# -------------------------------------
# DATA PARAMETERS
# Lonmin - Lonmax data : 98.108 - 99.339
# Latmin - Latmax data : 1.553 - 3.112
# Number of measurements : 273
# Source : /Users/simone/iCloud/Documents/Teaching/2023_2024/Seismic_Tomography/Lab/download/an_velocity/tomo/input_4.00s.txt
# -------------------------------------

# %%
tomo.grid.set_boundaries(latmin=tomo.latmin_data,
                             latmax=tomo.latmax_data,
                             lonmin=tomo.lonmin_data,
                             lonmax=tomo.lonmax_data)
# Out:
# *** GRID UPDATED ***
# -------------------------------------
# GRID PARAMETERS
# Lonmin - Lonmax : 97.886 - 99.500
# Latmin - Latmax : 1.500 - 3.500
# Number of cells : 12
# Grid cells of 0.500° : 12
# -------------------------------------

# %%
tomo.compile_coefficients(keep_empty_cells=True)
tomo.refine_parameterization(hitcounts=40, 
                              keep_empty_cells=True)    
tomo.refine_parameterization(hitcounts=40, 
                              keep_empty_cells=True)
# Out:
# *** GRID UPDATED ***
# -------------------------------------
# GRID PARAMETERS
# Lonmin - Lonmax : 97.886 - 99.500
# Latmin - Latmax : 1.500 - 3.500
# Number of cells : 33
# Grid cells of 0.500° : 5
# Grid cells of 0.250° : 28
# -------------------------------------
# *** GRID UPDATED ***
# -------------------------------------
# GRID PARAMETERS
# Lonmin - Lonmax : 97.886 - 99.500
# Latmin - Latmax : 1.500 - 3.500
# Number of cells : 69
# Grid cells of 0.500° : 5
# Grid cells of 0.250° : 16
# Grid cells of 0.125° : 48
# -------------------------------------

# %%
c = 1 / tomo.solve(rdamp=3e-3)
tomo.plot_map(tomo.grid.mesh, c, show=True)
# Out:
# (<cartopy.mpl.geocollection.GeoQuadMesh at 0x162060580>,
#  <matplotlib.colorbar.Colorbar at 0x162060940>)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/anaconda3/envs/obspy/lib/python3.9/site-packages/IPython/core/formatters.py:339, in BaseFormatter.__call__(self, obj)
#     337     pass
#     338 else:
# --> 339     return printer(obj)
#     340 # Finally look for special method names
#     341 method = get_real_method(obj, self.print_method)
#
# File ~/anaconda3/envs/obspy/lib/python3.9/site-packages/IPython/core/pylabtools.py:151, in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     148     from matplotlib.backend_bases import FigureCanvasBase
#     149     FigureCanvasBase(fig)
# --> 151 fig.canvas.print_figure(bytes_io, **kw)
#     152 data = bytes_io.getvalue()
#     153 if fmt == 'svg':
#
# File ~/anaconda3/envs/obspy/lib/python3.9/site-packages/matplotlib/backend_bases.py:2295, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2289     renderer = _get_renderer(
#    2290         self.figure,
#    2291         functools.partial(
#    2292             print_method, orientation=orientation)
#    2293     )
#    2294     with getattr(renderer, "_draw_disabled", nullcontext)():
# -> 2295         self.figure.draw(renderer)
#    2297 if bbox_inches:
#    2298     if bbox_inches == "tight":
#
# File ~/anaconda3/envs/obspy/lib/python3.9/site-packages/matplotlib/artist.py:73, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      71 @wraps(draw)
#      72 def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 73     result = draw(artist, renderer, *args, **kwargs)
#      74     if renderer._rasterizing:
#      75         renderer.stop_rasterizing()
#
# File ~/anaconda3/envs/obspy/lib/python3.9/site-packages/matplotlib/artist.py:50, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      47     if artist.get_agg_filter() is not None:
#      48         renderer.start_filter()
# ---> 50     return draw(artist, renderer)
#      51 finally:
#      52     if artist.get_agg_filter() is not None:
#
# File ~/anaconda3/envs/obspy/lib/python3.9/site-packages/matplotlib/figure.py:2810, in Figure.draw(self, renderer)
#    2807         # ValueError can occur when resizing a window.
#    2809 self.patch.draw(renderer)
# -> 2810 mimage._draw_list_compositing_images(
#    2811     renderer, self, artists, self.suppressComposite)
#    2813 for sfig in self.subfigs:
#    2814     sfig.draw(renderer)
#
# File ~/anaconda3/envs/obspy/lib/python3.9/site-packages/matplotlib/image.py:132, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130 if not_composite or not has_images:
#     131     for a in artists:
# --> 132         a.draw(renderer)
#     133 else:
#     134     # Composite any adjacent images together
#     135     image_group = []
#
# File ~/anaconda3/envs/obspy/lib/python3.9/site-packages/matplotlib/artist.py:50, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      47     if artist.get_agg_filter() is not None:
#      48         renderer.start_filter()
# ---> 50     return draw(artist, renderer)
#      51 finally:
#      52     if artist.get_agg_filter() is not None:
#
# File ~/anaconda3/envs/obspy/lib/python3.9/site-packages/cartopy/mpl/geoaxes.py:535, in GeoAxes.draw(self, renderer, **kwargs)
#     530         self.imshow(img, extent=extent, origin=origin,
#     531                     transform=factory.crs, *factory_args[1:],
#     532                     **factory_kwargs)
#     533 self._done_img_factory = True
# --> 535 return super().draw(renderer=renderer, **kwargs)
#
# File ~/anaconda3/envs/obspy/lib/python3.9/site-packages/matplotlib/artist.py:50, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      47     if artist.get_agg_filter() is not None:
#      48         renderer.start_filter()
# ---> 50     return draw(artist, renderer)
#      51 finally:
#      52     if artist.get_agg_filter() is not None:
#
# File ~/anaconda3/envs/obspy/lib/python3.9/site-packages/matplotlib/axes/_base.py:3082, in _AxesBase.draw(self, renderer)
#    3079         a.draw(renderer)
#    3080     renderer.stop_rasterizing()
# -> 3082 mimage._draw_list_compositing_images(
#    3083     renderer, self, artists, self.figure.suppressComposite)
#    3085 renderer.close_group('axes')
#    3086 self.stale = False
#
# File ~/anaconda3/envs/obspy/lib/python3.9/site-packages/matplotlib/image.py:132, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130 if not_composite or not has_images:
#     131     for a in artists:
# --> 132         a.draw(renderer)
#     133 else:
#     134     # Composite any adjacent images together
#     135     image_group = []
#
# File ~/anaconda3/envs/obspy/lib/python3.9/site-packages/matplotlib/artist.py:50, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      47     if artist.get_agg_filter() is not None:
#      48         renderer.start_filter()
# ---> 50     return draw(artist, renderer)
#      51 finally:
#      52     if artist.get_agg_filter() is not None:
#
# File ~/anaconda3/envs/obspy/lib/python3.9/site-packages/cartopy/mpl/feature_artist.py:152, in FeatureArtist.draw(self, renderer, *args, **kwargs)
#     150 except ValueError:
#     151     warnings.warn('Unable to determine extent. Defaulting to global.')
# --> 152 geoms = self._feature.intersecting_geometries(extent)
#     154 # Combine all the keyword args in priority order.
#     155 prepared_kwargs = style_merge(self._feature.kwargs,
#     156                               self._kwargs,
#     157                               kwargs)
#
# File ~/anaconda3/envs/obspy/lib/python3.9/site-packages/cartopy/feature/__init__.py:305, in NaturalEarthFeature.intersecting_geometries(self, extent)
#     298 """
#     299 Returns an iterator of shapely geometries that intersect with
#     300 the given extent.
#     301 The extent is assumed to be in the CRS of the feature.
#     302 If extent is None, the method returns all geometries for this dataset.
#     303 """
#     304 self.scaler.scale_from_extent(extent)
# --> 305 return super().intersecting_geometries(extent)
#
# File ~/anaconda3/envs/obspy/lib/python3.9/site-packages/cartopy/feature/__init__.py:108, in Feature.intersecting_geometries(self, extent)
#     105 if extent is not None and not np.isnan(extent[0]):
#     106     extent_geom = sgeom.box(extent[0], extent[2],
#     107                             extent[1], extent[3])
# --> 108     return (geom for geom in self.geometries() if
#     109             geom is not None and extent_geom.intersects(geom))
#     110 else:
#     111     return self.geometries()
#
# File ~/anaconda3/envs/obspy/lib/python3.9/site-packages/cartopy/feature/__init__.py:290, in NaturalEarthFeature.geometries(self)
#     286 if key not in _NATURAL_EARTH_GEOM_CACHE:
#     287     path = shapereader.natural_earth(resolution=self.scale,
#     288                                      category=self.category,
#     289                                      name=self.name)
# --> 290     geometries = tuple(shapereader.Reader(path).geometries())
#     291     _NATURAL_EARTH_GEOM_CACHE[key] = geometries
#     292 else:
#
# File ~/anaconda3/envs/obspy/lib/python3.9/site-packages/cartopy/io/shapereader.py:138, in BasicReader.__init__(self, filename, bbox)
#     136 self._reader = reader = shapefile.Reader(filename)
#     137 if reader.shp is None or reader.shx is None or reader.dbf is None:
# --> 138     raise ValueError("Incomplete shapefile definition "
#     139                      "in '%s'." % filename)
#     141 self._fields = self._reader.fields
#
# ValueError: Incomplete shapefile definition in '/Users/simone/.local/share/cartopy/shapefiles/natural_earth/physical/ne_110m_land.shp'.

# %%
restest = tomo.checkerboard_test(kx=6,
                                 ky=6,
                                 latmin=tomo.grid.latmin,
                                 latmax=tomo.grid.latmax,
                                 lonmin=tomo.grid.lonmin,
                                 lonmax=tomo.grid.lonmax,
                                 cell_size=0.25,
                                 anom_amp=0.1,
                                 noise=0,
                                 rdamp=3e-3)

input_model = 1 / restest['synth_model']
input_mesh = restest['mesh']
retrieved_model = 1 / restest['retrieved_model']

tomo.plot_map(tomo.grid.mesh, retrieved_model)
tomo.plot_map(input_mesh, input_model)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/anaconda3/envs/obspy/lib/python3.9/site-packages/IPython/core/formatters.py:339, in BaseFormatter.__call__(self, obj)
#     337     pass
#     338 else:
# --> 339     return printer(obj)
#     340 # Finally look for special method names
#     341 method = get_real_method(obj, self.print_method)
#
# File ~/anaconda3/envs/obspy/lib/python3.9/site-packages/IPython/core/pylabtools.py:151, in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     148     from matplotlib.backend_bases import FigureCanvasBase
#     149     FigureCanvasBase(fig)
# --> 151 fig.canvas.print_figure(bytes_io, **kw)
#     152 data = bytes_io.getvalue()
#     153 if fmt == 'svg':
#
# File ~/anaconda3/envs/obspy/lib/python3.9/site-packages/matplotlib/backend_bases.py:2295, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2289     renderer = _get_renderer(
#    2290         self.figure,
#    2291         functools.partial(
#    2292             print_method, orientation=orientation)
#    2293     )
#    2294     with getattr(renderer, "_draw_disabled", nullcontext)():
# -> 2295         self.figure.draw(renderer)
#    2297 if bbox_inches:
#    2298     if bbox_inches == "tight":
#
# File ~/anaconda3/envs/obspy/lib/python3.9/site-packages/matplotlib/artist.py:73, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      71 @wraps(draw)
#      72 def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 73     result = draw(artist, renderer, *args, **kwargs)
#      74     if renderer._rasterizing:
#      75         renderer.stop_rasterizing()
#
# File ~/anaconda3/envs/obspy/lib/python3.9/site-packages/matplotlib/artist.py:50, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      47     if artist.get_agg_filter() is not None:
#      48         renderer.start_filter()
# ---> 50     return draw(artist, renderer)
#      51 finally:
#      52     if artist.get_agg_filter() is not None:
#
# File ~/anaconda3/envs/obspy/lib/python3.9/site-packages/matplotlib/figure.py:2810, in Figure.draw(self, renderer)
#    2807         # ValueError can occur when resizing a window.
#    2809 self.patch.draw(renderer)
# -> 2810 mimage._draw_list_compositing_images(
#    2811     renderer, self, artists, self.suppressComposite)
#    2813 for sfig in self.subfigs:
#    2814     sfig.draw(renderer)
#
# File ~/anaconda3/envs/obspy/lib/python3.9/site-packages/matplotlib/image.py:132, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130 if not_composite or not has_images:
#     131     for a in artists:
# --> 132         a.draw(renderer)
#     133 else:
#     134     # Composite any adjacent images together
#     135     image_group = []
#
# File ~/anaconda3/envs/obspy/lib/python3.9/site-packages/matplotlib/artist.py:50, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      47     if artist.get_agg_filter() is not None:
#      48         renderer.start_filter()
# ---> 50     return draw(artist, renderer)
#      51 finally:
#      52     if artist.get_agg_filter() is not None:
#
# File ~/anaconda3/envs/obspy/lib/python3.9/site-packages/cartopy/mpl/geoaxes.py:535, in GeoAxes.draw(self, renderer, **kwargs)
#     530         self.imshow(img, extent=extent, origin=origin,
#     531                     transform=factory.crs, *factory_args[1:],
#     532                     **factory_kwargs)
#     533 self._done_img_factory = True
# --> 535 return super().draw(renderer=renderer, **kwargs)
#
# File ~/anaconda3/envs/obspy/lib/python3.9/site-packages/matplotlib/artist.py:50, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      47     if artist.get_agg_filter() is not None:
#      48         renderer.start_filter()
# ---> 50     return draw(artist, renderer)
#      51 finally:
#      52     if artist.get_agg_filter() is not None:
#
# File ~/anaconda3/envs/obspy/lib/python3.9/site-packages/matplotlib/axes/_base.py:3082, in _AxesBase.draw(self, renderer)
#    3079         a.draw(renderer)
#    3080     renderer.stop_rasterizing()
# -> 3082 mimage._draw_list_compositing_images(
#    3083     renderer, self, artists, self.figure.suppressComposite)
#    3085 renderer.close_group('axes')
#    3086 self.stale = False
#
# File ~/anaconda3/envs/obspy/lib/python3.9/site-packages/matplotlib/image.py:132, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130 if not_composite or not has_images:
#     131     for a in artists:
# --> 132         a.draw(renderer)
#     133 else:
#     134     # Composite any adjacent images together
#     135     image_group = []
#
# File ~/anaconda3/envs/obspy/lib/python3.9/site-packages/matplotlib/artist.py:50, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      47     if artist.get_agg_filter() is not None:
#      48         renderer.start_filter()
# ---> 50     return draw(artist, renderer)
#      51 finally:
#      52     if artist.get_agg_filter() is not None:
#
# File ~/anaconda3/envs/obspy/lib/python3.9/site-packages/cartopy/mpl/feature_artist.py:152, in FeatureArtist.draw(self, renderer, *args, **kwargs)
#     150 except ValueError:
#     151     warnings.warn('Unable to determine extent. Defaulting to global.')
# --> 152 geoms = self._feature.intersecting_geometries(extent)
#     154 # Combine all the keyword args in priority order.
#     155 prepared_kwargs = style_merge(self._feature.kwargs,
#     156                               self._kwargs,
#     157                               kwargs)
#
# File ~/anaconda3/envs/obspy/lib/python3.9/site-packages/cartopy/feature/__init__.py:305, in NaturalEarthFeature.intersecting_geometries(self, extent)
#     298 """
#     299 Returns an iterator of shapely geometries that intersect with
#     300 the given extent.
#     301 The extent is assumed to be in the CRS of the feature.
#     302 If extent is None, the method returns all geometries for this dataset.
#     303 """
#     304 self.scaler.scale_from_extent(extent)
# --> 305 return super().intersecting_geometries(extent)
#
# File ~/anaconda3/envs/obspy/lib/python3.9/site-packages/cartopy/feature/__init__.py:108, in Feature.intersecting_geometries(self, extent)
#     105 if extent is not None and not np.isnan(extent[0]):
#     106     extent_geom = sgeom.box(extent[0], extent[2],
#     107                             extent[1], extent[3])
# --> 108     return (geom for geom in self.geometries() if
#     109             geom is not None and extent_geom.intersects(geom))
#     110 else:
#     111     return self.geometries()
#
# File ~/anaconda3/envs/obspy/lib/python3.9/site-packages/cartopy/feature/__init__.py:290, in NaturalEarthFeature.geometries(self)
#     286 if key not in _NATURAL_EARTH_GEOM_CACHE:
#     287     path = shapereader.natural_earth(resolution=self.scale,
#     288                                      category=self.category,
#     289                                      name=self.name)
# --> 290     geometries = tuple(shapereader.Reader(path).geometries())
#     291     _NATURAL_EARTH_GEOM_CACHE[key] = geometries
#     292 else:
#
# File ~/anaconda3/envs/obspy/lib/python3.9/site-packages/cartopy/io/shapereader.py:138, in BasicReader.__init__(self, filename, bbox)
#     136 self._reader = reader = shapefile.Reader(filename)
#     137 if reader.shp is None or reader.shx is None or reader.dbf is None:
# --> 138     raise ValueError("Incomplete shapefile definition "
#     139                      "in '%s'." % filename)
#     141 self._fields = self._reader.fields
#
# ValueError: Incomplete shapefile definition in '/Users/simone/.local/share/cartopy/shapefiles/natural_earth/physical/ne_110m_land.shp'.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/anaconda3/envs/obspy/lib/python3.9/site-packages/IPython/core/formatters.py:339, in BaseFormatter.__call__(self, obj)
#     337     pass
#     338 else:
# --> 339     return printer(obj)
#     340 # Finally look for special method names
#     341 method = get_real_method(obj, self.print_method)
#
# File ~/anaconda3/envs/obspy/lib/python3.9/site-packages/IPython/core/pylabtools.py:151, in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     148     from matplotlib.backend_bases import FigureCanvasBase
#     149     FigureCanvasBase(fig)
# --> 151 fig.canvas.print_figure(bytes_io, **kw)
#     152 data = bytes_io.getvalue()
#     153 if fmt == 'svg':
#
# File ~/anaconda3/envs/obspy/lib/python3.9/site-packages/matplotlib/backend_bases.py:2295, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2289     renderer = _get_renderer(
#    2290         self.figure,
#    2291         functools.partial(
#    2292             print_method, orientation=orientation)
#    2293     )
#    2294     with getattr(renderer, "_draw_disabled", nullcontext)():
# -> 2295         self.figure.draw(renderer)
#    2297 if bbox_inches:
#    2298     if bbox_inches == "tight":
#
# File ~/anaconda3/envs/obspy/lib/python3.9/site-packages/matplotlib/artist.py:73, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      71 @wraps(draw)
#      72 def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 73     result = draw(artist, renderer, *args, **kwargs)
#      74     if renderer._rasterizing:
#      75         renderer.stop_rasterizing()
#
# File ~/anaconda3/envs/obspy/lib/python3.9/site-packages/matplotlib/artist.py:50, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      47     if artist.get_agg_filter() is not None:
#      48         renderer.start_filter()
# ---> 50     return draw(artist, renderer)
#      51 finally:
#      52     if artist.get_agg_filter() is not None:
#
# File ~/anaconda3/envs/obspy/lib/python3.9/site-packages/matplotlib/figure.py:2810, in Figure.draw(self, renderer)
#    2807         # ValueError can occur when resizing a window.
#    2809 self.patch.draw(renderer)
# -> 2810 mimage._draw_list_compositing_images(
#    2811     renderer, self, artists, self.suppressComposite)
#    2813 for sfig in self.subfigs:
#    2814     sfig.draw(renderer)
#
# File ~/anaconda3/envs/obspy/lib/python3.9/site-packages/matplotlib/image.py:132, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130 if not_composite or not has_images:
#     131     for a in artists:
# --> 132         a.draw(renderer)
#     133 else:
#     134     # Composite any adjacent images together
#     135     image_group = []
#
# File ~/anaconda3/envs/obspy/lib/python3.9/site-packages/matplotlib/artist.py:50, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      47     if artist.get_agg_filter() is not None:
#      48         renderer.start_filter()
# ---> 50     return draw(artist, renderer)
#      51 finally:
#      52     if artist.get_agg_filter() is not None:
#
# File ~/anaconda3/envs/obspy/lib/python3.9/site-packages/cartopy/mpl/geoaxes.py:535, in GeoAxes.draw(self, renderer, **kwargs)
#     530         self.imshow(img, extent=extent, origin=origin,
#     531                     transform=factory.crs, *factory_args[1:],
#     532                     **factory_kwargs)
#     533 self._done_img_factory = True
# --> 535 return super().draw(renderer=renderer, **kwargs)
#
# File ~/anaconda3/envs/obspy/lib/python3.9/site-packages/matplotlib/artist.py:50, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      47     if artist.get_agg_filter() is not None:
#      48         renderer.start_filter()
# ---> 50     return draw(artist, renderer)
#      51 finally:
#      52     if artist.get_agg_filter() is not None:
#
# File ~/anaconda3/envs/obspy/lib/python3.9/site-packages/matplotlib/axes/_base.py:3082, in _AxesBase.draw(self, renderer)
#    3079         a.draw(renderer)
#    3080     renderer.stop_rasterizing()
# -> 3082 mimage._draw_list_compositing_images(
#    3083     renderer, self, artists, self.figure.suppressComposite)
#    3085 renderer.close_group('axes')
#    3086 self.stale = False
#
# File ~/anaconda3/envs/obspy/lib/python3.9/site-packages/matplotlib/image.py:132, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130 if not_composite or not has_images:
#     131     for a in artists:
# --> 132         a.draw(renderer)
#     133 else:
#     134     # Composite any adjacent images together
#     135     image_group = []
#
# File ~/anaconda3/envs/obspy/lib/python3.9/site-packages/matplotlib/artist.py:50, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      47     if artist.get_agg_filter() is not None:
#      48         renderer.start_filter()
# ---> 50     return draw(artist, renderer)
#      51 finally:
#      52     if artist.get_agg_filter() is not None:
#
# File ~/anaconda3/envs/obspy/lib/python3.9/site-packages/cartopy/mpl/feature_artist.py:152, in FeatureArtist.draw(self, renderer, *args, **kwargs)
#     150 except ValueError:
#     151     warnings.warn('Unable to determine extent. Defaulting to global.')
# --> 152 geoms = self._feature.intersecting_geometries(extent)
#     154 # Combine all the keyword args in priority order.
#     155 prepared_kwargs = style_merge(self._feature.kwargs,
#     156                               self._kwargs,
#     157                               kwargs)
#
# File ~/anaconda3/envs/obspy/lib/python3.9/site-packages/cartopy/feature/__init__.py:305, in NaturalEarthFeature.intersecting_geometries(self, extent)
#     298 """
#     299 Returns an iterator of shapely geometries that intersect with
#     300 the given extent.
#     301 The extent is assumed to be in the CRS of the feature.
#     302 If extent is None, the method returns all geometries for this dataset.
#     303 """
#     304 self.scaler.scale_from_extent(extent)
# --> 305 return super().intersecting_geometries(extent)
#
# File ~/anaconda3/envs/obspy/lib/python3.9/site-packages/cartopy/feature/__init__.py:108, in Feature.intersecting_geometries(self, extent)
#     105 if extent is not None and not np.isnan(extent[0]):
#     106     extent_geom = sgeom.box(extent[0], extent[2],
#     107                             extent[1], extent[3])
# --> 108     return (geom for geom in self.geometries() if
#     109             geom is not None and extent_geom.intersects(geom))
#     110 else:
#     111     return self.geometries()
#
# File ~/anaconda3/envs/obspy/lib/python3.9/site-packages/cartopy/feature/__init__.py:290, in NaturalEarthFeature.geometries(self)
#     286 if key not in _NATURAL_EARTH_GEOM_CACHE:
#     287     path = shapereader.natural_earth(resolution=self.scale,
#     288                                      category=self.category,
#     289                                      name=self.name)
# --> 290     geometries = tuple(shapereader.Reader(path).geometries())
#     291     _NATURAL_EARTH_GEOM_CACHE[key] = geometries
#     292 else:
#
# File ~/anaconda3/envs/obspy/lib/python3.9/site-packages/cartopy/io/shapereader.py:138, in BasicReader.__init__(self, filename, bbox)
#     136 self._reader = reader = shapefile.Reader(filename)
#     137 if reader.shp is None or reader.shx is None or reader.dbf is None:
# --> 138     raise ValueError("Incomplete shapefile definition "
#     139                      "in '%s'." % filename)
#     141 self._fields = self._reader.fields
#
# ValueError: Incomplete shapefile definition in '/Users/simone/.local/share/cartopy/shapefiles/natural_earth/physical/ne_110m_land.shp'.
